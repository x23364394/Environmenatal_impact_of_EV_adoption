# %% [markdown]
# # Importing Washington AQI daily summary data via API

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
# EPA API account credentials
email = "ch.vishal400@gmail.com"  
api_key = "sandkit13"

# %%
# link to reteive data
url = "https://aqs.epa.gov/data/api/dailyData/byState"

# parameters of url to make it work
params = {
    "email": email,
    "key": api_key,
    "param": "88101",  # PM2.5 (Particulate Matter pollution Local Conditions)
    "bdate": "20240101",  # Begining date of data collection January 1, 2024
    "edate": "20241231",  # Ending date of data collection December 31, 2024
    "state": "53" }  # washington state code

# %%
# function to retrieve data from EPA API
def aqi_data(url, params):
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data["Header"][0]["status"] == "Success":
            return data["Data"]
        else:
            print("API request failed:", data["Header"][0]["error"])
            return None
    else:
        print(f"HTTP Error: {response.status_code}")
        return None

# %%
# gathering data of washington aqi
print("Gathering data for Washington, 2024...")
wa_aqi_data = aqi_data(url, params)
# Out:
# Gathering data for Washington, 2024...

# %%
# covert data to save in csv format
if wa_aqi_data:
    df = pd.DataFrame(wa_aqi_data)
    
    print("Columns Available in the data:", df.columns.tolist())  # print available columns to check
    print(f"Total Columns: {len(df.columns)}") # print total number of columns
    print(f"Total Rows: {len(df)}") # print total number of rows 
    
    file = "washington_aqi.csv" # save file in csv
    df.to_csv(file, index=False) 
    print(f"Data saved to {file}")
    
    print("\nFirst 5 rows of the data:") # to check few rows
    print(df.head())
else:
    print("no data found.")
# Out:
# Columns Available in the data: ['state_code', 'county_code', 'site_number', 'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter', 'sample_duration_code', 'sample_duration', 'pollutant_standard', 'date_local', 'units_of_measure', 'event_type', 'observation_count', 'observation_percent', 'validity_indicator', 'arithmetic_mean', 'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method', 'local_site_name', 'site_address', 'state', 'county', 'city', 'cbsa_code', 'cbsa', 'date_of_last_change']
# Total Columns: 32
# Total Rows: 70939
# Data saved to washington_aqi.csv
#
# First 5 rows of the data:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         53         033        0030          88101    5  47.597222
# 1         53         033        0030          88101    5  47.597222
# 2         53         033        0030          88101    5  47.597222
# 3         53         033        0030          88101    5  47.597222
# 4         53         033        0030          88101    5  47.597222
#
#     longitude  datum                 parameter sample_duration_code  ...  \
# 0 -122.319722  WGS84  PM2.5 - Local Conditions                    X  ...
# 1 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 2 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 3 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 4 -122.319722  WGS84  PM2.5 - Local Conditions                    X  ...
#
#   method_code                                             method  \
# 0         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 1         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 3         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#          local_site_name   site_address       state  county     city  \
# 0  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 1  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 2  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 3  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 4  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
#
#   cbsa_code                         cbsa  date_of_last_change
# 0     42660  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 1     42660  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 2     42660  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 3     42660  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 4     42660  Seattle-Tacoma-Bellevue, WA           2025-04-04
#
# [5 rows x 32 columns]

# %% [markdown]
# # Connection to MongoDB

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient('mongodb://localhost:27017/')
dbname = client['washington_aqi']
collection_name = dbname['aqi_daily_summary']

# %%
# Read CSV data 
wa_aqi_data = pd.read_csv('washington_aqi.csv') # washington aqi data

print(wa_aqi_data.head())
print(wa_aqi_data.tail())

# count total number of rows
total_rows = len(wa_aqi_data)
print(f" Total number of rows: {total_rows}")
# Out:
#    state_code  county_code  site_number  parameter_code  poc   latitude  \
# 0          53           33           30           88101    5  47.597222
# 1          53           33           30           88101    5  47.597222
# 2          53           33           30           88101    5  47.597222
# 3          53           33           30           88101    5  47.597222
# 4          53           33           30           88101    5  47.597222
#
#     longitude  datum                 parameter sample_duration_code  ...  \
# 0 -122.319722  WGS84  PM2.5 - Local Conditions                    X  ...
# 1 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 2 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 3 -122.319722  WGS84  PM2.5 - Local Conditions                    1  ...
# 4 -122.319722  WGS84  PM2.5 - Local Conditions                    X  ...
#
#   method_code                                             method  \
# 0         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 1         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 3         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#          local_site_name   site_address       state  county     city  \
# 0  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 1  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 2  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 3  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
# 4  Seattle-10th & Weller  10th & Weller  Washington    King  Seattle
#
#   cbsa_code                         cbsa  date_of_last_change
# 0   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 1   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 2   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 3   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 4   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
#
# [5 rows x 32 columns]
#        state_code  county_code  site_number  parameter_code  poc   latitude  \
# 70934          53           61           22           88101    5  47.893611
# 70935          53           61           22           88101    5  47.893611
# 70936          53           61           22           88101    5  47.893611
# 70937          53           61           22           88101    5  47.893611
# 70938          53           61           22           88101    5  47.893611
#
#         longitude  datum                 parameter sample_duration_code  ...  \
# 70934 -122.269722  WGS84  PM2.5 - Local Conditions                    X  ...
# 70935 -122.269722  WGS84  PM2.5 - Local Conditions                    X  ...
# 70936 -122.269722  WGS84  PM2.5 - Local Conditions                    X  ...
# 70937 -122.269722  WGS84  PM2.5 - Local Conditions                    X  ...
# 70938 -122.269722  WGS84  PM2.5 - Local Conditions                    X  ...
#
#       method_code                                             method  \
# 70934         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 70935         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 70936         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 70937         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 70938         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#       local_site_name           site_address       state     county     city  \
# 70934             NaN  11401 Beverly Park Rd  Washington  Snohomish  Everett
# 70935             NaN  11401 Beverly Park Rd  Washington  Snohomish  Everett
# 70936             NaN  11401 Beverly Park Rd  Washington  Snohomish  Everett
# 70937             NaN  11401 Beverly Park Rd  Washington  Snohomish  Everett
# 70938             NaN  11401 Beverly Park Rd  Washington  Snohomish  Everett
#
#       cbsa_code                         cbsa  date_of_last_change
# 70934   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 70935   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 70936   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 70937   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
# 70938   42660.0  Seattle-Tacoma-Bellevue, WA           2025-04-04
#
# [5 rows x 32 columns]
#  Total number of rows: 70939

# %%
# convert dataframe to dictionary format
data = wa_aqi_data.to_dict(orient='records')

# insert data in dictonary format into mongodb
collection_name.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67f8583fa48cef0646241d45'), ObjectId('67f8583fa48cef0646241d46'), ObjectId('67f8583fa48cef0646241d47'), ObjectId('67f8583fa48cef0646241d48'), ObjectId('67f8583fa48cef0646241d49'), ObjectId('67f8583fa48cef0646241d4a'), ObjectId('67f8583fa48cef0646241d4b'), ObjectId('67f8583fa48cef0646241d4c'), ObjectId('67f8583fa48cef0646241d4d'), ObjectId('67f8583fa48cef0646241d4e'), ObjectId('67f8583fa48cef0646241d4f'), ObjectId('67f8583fa48cef0646241d50'), ObjectId('67f8583fa48cef0646241d51'), ObjectId('67f8583fa48cef0646241d52'), ObjectId('67f8583fa48cef0646241d53'), ObjectId('67f8583fa48cef0646241d54'), ObjectId('67f8583fa48cef0646241d55'), ObjectId('67f8583fa48cef0646241d56'), ObjectId('67f8583fa48cef0646241d57'), ObjectId('67f8583fa48cef0646241d58'), ObjectId('67f8583fa48cef0646241d59'), ObjectId('67f8583fa48cef0646241d5a'), ObjectId('67f8583fa48cef0646241d5b'), ObjectId('67f8583fa48cef0646241d5c'), ObjectId('67f8583fa48cef0646241d5d'), ObjectId('67f8583fa48cef0646241d5e'), ObjectId('67f8583fa48cef0646241d5f'), ObjectId('67f8583fa48cef0646241d60'), ObjectId('67f8583fa48cef0646241d61'), ObjectId('67f8583fa48cef0646241d62'), ObjectId('67f8583fa48cef0646241d63'), ObjectId('67f8583fa48cef0646241d64'), ObjectId('67f8583fa48cef0646241d65'), ObjectId('67f8583fa48cef0646241d66'), ObjectId('67f8583fa48cef0646241d67'), ObjectId('67f8583fa48cef0646241d68'), ObjectId('67f8583fa48cef0646241d69'), ObjectId('67f8583fa48cef0646241d6a'), ObjectId('67f8583fa48cef0646241d6b'), ObjectId('67f8583fa48cef0646241d6c'), ObjectId('67f8583fa48cef0646241d6d'), ObjectId('67f8583fa48cef0646241d6e'), ObjectId('67f8583fa48cef0646241d6f'), ObjectId('67f8583fa48cef0646241d70'), ObjectId('67f8583fa48cef0646241d71'), ObjectId('67f8583fa48cef0646241d72'), ObjectId('67f8583fa48cef0646241d73'), ObjectId('67f8583fa48cef0646241d74'), ObjectId('67f8583fa48cef0646241d75'), ObjectId('67f8583fa48cef0646241d76'), ObjectId('67f8583fa48cef0646241d77'), ObjectId('67f8583fa48cef0646241d78'), ObjectId('67f8583fa48cef0646241d79'), ObjectId('67f8583fa48cef0646241d7a'), ObjectId('67f8583fa48cef0646241d7b'), ObjectId('67f8583fa48cef0646241d7c'), ObjectId('67f8583fa48cef0646241d7d'), ObjectId('67f8583fa48cef0646241d7e'), ObjectId('67f8583fa48cef0646241d7f'), ObjectId('67f8583fa48cef0646241d80'), ObjectId('67f8583fa48cef0646241d81'), ObjectId('67f8583fa48cef0646241d82'), ObjectId('67f8583fa48cef0646241d83'), ObjectId('67f8583fa48cef0646241d84'), ObjectId('67f8583fa48cef0646241d85'), ObjectId('67f8583fa48cef0646241d86'), ObjectId('67f8583fa48cef0646241d87'), ObjectId('67f8583fa48cef0646241d88'), ObjectId('67f8583fa48cef0646241d89'), ObjectId('67f8583fa48cef0646241d8a'), ObjectId('67f8583fa48cef0646241d8b'), ObjectId('67f8583fa48cef0646241d8c'), ObjectId('67f8583fa48cef0646241d8d'), ObjectId('67f8583fa48cef0646241d8e'), ObjectId('67f8583fa48cef0646241d8f'), ObjectId('67f8583fa48cef0646241d90'), ObjectId('67f8583fa48cef0646241d91'), ObjectId('67f8583fa48cef0646241d92'), ObjectId('67f8583fa48cef0646241d93'), ObjectId('67f8583fa48cef0646241d94'), ObjectId('67f8583fa48cef0646241d95'), ObjectId('67f8583fa48cef0646241d96'), ObjectId('67f8583fa48cef0646241d97'), ObjectId('67f8583fa48cef0646241d98'), ObjectId('67f8583fa48cef0646241d99'), ObjectId('67f8583fa48cef0646241d9a'), ObjectId('67f8583fa48cef0646241d9b'), ObjectId('67f8583fa48cef0646241d9c'), ObjectId('67f8583fa48cef0646241d9d'), ObjectId('67f8583fa48cef0646241d9e'), ObjectId('67f8583fa48cef0646241d9f'), ObjectId('67f8583fa48cef0646241da0'), ObjectId('67f8583fa48cef0646241da1'), ObjectId('67f8583fa48cef0646241da2'), ObjectId('67f8583fa48cef0646241da3'), ObjectId('67f8583fa48cef0646241da4'), ObjectId('67f8583fa48cef0646241da5'), ObjectId('67f8583fa48cef0646241da6'), ObjectId('67f8583fa48cef0646241da7'), ObjectId('67f8583fa48cef0646241da8'), ObjectId('67f8583fa48cef0646241da9'), ObjectId('67f8583fa48cef0646241daa'), ObjectId('67f8583fa48cef0646241dab'), ObjectId('67f8583fa48cef0646241dac'), ObjectId('67f8583fa48cef064624 ...

# %%
# to check inserted data
for col in collection_name.find().limit(10):
    print(col)
# Out:
# {'_id': ObjectId('67f8583fa48cef0646241d45'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2012', 'date_local': '2024-01-03', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 4.9, 'first_max_value': 4.9, 'first_max_hour': 0, 'aqi': 27.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d46'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': '1', 'sample_duration': '1 HOUR', 'pollutant_standard': nan, 'date_local': '2024-01-01', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.083333, 'first_max_value': 43.0, 'first_max_hour': 6, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d47'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': '1', 'sample_duration': '1 HOUR', 'pollutant_standard': nan, 'date_local': '2024-01-02', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 14.875, 'first_max_value': 29.0, 'first_max_hour': 8, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d48'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': '1', 'sample_duration': '1 HOUR', 'pollutant_standard': nan, 'date_local': '2024-01-03', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 23, 'observation_percent': 96.0, 'validity_indicator': 'Y', 'arithmetic_mean': 4.956522, 'first_max_value': 14.0, 'first_max_hour': 8, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d49'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2006', 'date_local': '2024-01-01', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.0, 'first_max_value': 20.0, 'first_max_hour': 0, 'aqi': 71.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d4a'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2006', 'date_local': '2024-01-02', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 14.8, 'first_max_value': 14.8, 'first_max_hour': 0, 'aqi': 62.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d4b'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2006', 'date_local': '2024-01-03', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 4.9, 'first_max_value': 4.9, 'first_max_hour': 0, 'aqi': 27.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d4c'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 Annual 2006', 'date_local': '2024-01-01', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.0, 'first_max_value': 20.0, 'first_max_hour': 0, 'aqi': 71.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d4d'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2012', 'date_local': '2024-01-01', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.0, 'first_max_value': 20.0, 'first_max_hour': 0, 'aqi': 71.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d4e'), 'state_code': 53, 'county_code': 33, 'site_number': 30, 'parameter_code': 88101, 'poc': 5, 'latitude': 47.597222, 'longitude': -122.319722, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration_code': 'X', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2012', 'date_local': '2024-01-02', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'No Events', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 14.8, 'first_max_value': 14.8, 'first_max_hour': 0, 'aqi': 62.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'site_address': '10th & Weller', 'state': 'Washington', 'county': 'King', 'city': 'Seattle', 'cbsa_code': 42660.0, 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}

# %%
# to count the number of the docs in the collection
total_docs = collection_name.count_documents({})
print(f"total number of rows/docs in the collection: {total_docs}")
# Out:
# total number of rows/docs in the collection: 70939

# %%
# Dropped columns that are not required

drop_columns = {"state_code": "","state": "",
                "site_number": "","parameter_code": "",
                "poc": "","latitude": "","longitude": "",
                "cbsa_code": "","sample_duration_code": "",
                "sample_duration": "","pollutant_standard": "",
                "units_of_measure": "","event_type": "",
                "site_address": "","site_address": ""}

collection_name.update_many({}, {"$unset":drop_columns}) # empty string values are just placeholders for $unset
# Out:
# UpdateResult({'n': 70939, 'nModified': 70939, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# to check the field names and keys 
updated_collection = collection_name.find_one()
print(updated_collection.keys())
# Out:
# dict_keys(['_id', 'county_code', 'datum', 'parameter', 'date_local', 'observation_count', 'observation_percent', 'validity_indicator', 'arithmetic_mean', 'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method', 'local_site_name', 'county', 'city', 'cbsa', 'date_of_last_change'])

# %%
# to check 5 docs in the collection

for doc in collection_name.find().limit(5):
    print(doc)
# Out:
# {'_id': ObjectId('67f8583fa48cef0646241d45'), 'county_code': 33, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'date_local': '2024-01-03', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 4.9, 'first_max_value': 4.9, 'first_max_hour': 0, 'aqi': 27.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'county': 'King', 'city': 'Seattle', 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d46'), 'county_code': 33, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'date_local': '2024-01-01', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.083333, 'first_max_value': 43.0, 'first_max_hour': 6, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'county': 'King', 'city': 'Seattle', 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d47'), 'county_code': 33, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'date_local': '2024-01-02', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 14.875, 'first_max_value': 29.0, 'first_max_hour': 8, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'county': 'King', 'city': 'Seattle', 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d48'), 'county_code': 33, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'date_local': '2024-01-03', 'observation_count': 23, 'observation_percent': 96.0, 'validity_indicator': 'Y', 'arithmetic_mean': 4.956522, 'first_max_value': 14.0, 'first_max_hour': 8, 'aqi': nan, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'county': 'King', 'city': 'Seattle', 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}
# {'_id': ObjectId('67f8583fa48cef0646241d49'), 'county_code': 33, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'date_local': '2024-01-01', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 20.0, 'first_max_value': 20.0, 'first_max_hour': 0, 'aqi': 71.0, 'method_code': 170, 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'Seattle-10th & Weller', 'county': 'King', 'city': 'Seattle', 'cbsa': 'Seattle-Tacoma-Bellevue, WA', 'date_of_last_change': '2025-04-04'}

# %% [markdown]
# # Preprocessing of the Data

# %%
import pandas as pd

df_data = collection_name.find() # retrieving all documents from the collection

df = pd.DataFrame(list(df_data)) # converted to dataframe

# %%
# removed the id column
df.drop(columns=['_id'], inplace= True)

# %%
df.head()
# Out:
#    county_code  datum                 parameter  date_local  \
# 0           33  WGS84  PM2.5 - Local Conditions  2024-01-03
# 1           33  WGS84  PM2.5 - Local Conditions  2024-01-01
# 2           33  WGS84  PM2.5 - Local Conditions  2024-01-02
# 3           33  WGS84  PM2.5 - Local Conditions  2024-01-03
# 4           33  WGS84  PM2.5 - Local Conditions  2024-01-01
#
#    observation_count  observation_percent validity_indicator  arithmetic_mean  \
# 0                  1                100.0                  Y         4.900000
# 1                 24                100.0                  Y        20.083333
# 2                 24                100.0                  Y        14.875000
# 3                 23                 96.0                  Y         4.956522
# 4                  1                100.0                  Y        20.000000
#
#    first_max_value  first_max_hour   aqi  method_code  \
# 0              4.9               0  27.0          170
# 1             43.0               6   NaN          170
# 2             29.0               8   NaN          170
# 3             14.0               8   NaN          170
# 4             20.0               0  71.0          170
#
#                                               method        local_site_name  \
# 0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 1  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 2  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 3  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 4  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
#
#   county     city                         cbsa date_of_last_change
# 0   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04
# 1   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04
# 2   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04
# 3   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04
# 4   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04

# %% [markdown]
# #### Removing duplicates

# %%
df.drop_duplicates(inplace= True)

# %%
df.dropna(subset=['aqi'], inplace = True) # dropped duplicate rows

# %%
print(df.isnull().sum()) # checking if there are any missing values
# Out:
# county_code              0
# datum                    0
# parameter                0
# date_local               0
# observation_count        0
# observation_percent      0
# validity_indicator       0
# arithmetic_mean          0
# first_max_value          0
# first_max_hour           0
# aqi                      0
# method_code              0
# method                   0
# local_site_name        226
# county                   0
# city                     0
# cbsa                   411
# date_of_last_change      0
# dtype: int64

# %%
df['cbsa'].fillna('Unknown', inplace = True)  #filling missing values in column 'cbsa'
# Out:
# /var/folders/gw/ck0g9c4n03ld5qbdn_p8skp00000gn/T/ipykernel_11988/2236268178.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cbsa'].fillna('Unknown', inplace = True)  #filling missing values in column 'cbsa'

# %%
df['local_site_name'].fillna('Unknown', inplace = True) #filling missing values in column 'local_site_name'
# Out:
# /var/folders/gw/ck0g9c4n03ld5qbdn_p8skp00000gn/T/ipykernel_11988/1897304943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['local_site_name'].fillna('Unknown', inplace = True) #filling missing values in column 'local_site_name'

# %%
# convert normal date format to datetime, so that year and month can be extracted
df['date_local'] = pd.to_datetime(df['date_local'], errors = 'coerce')

# %%
print(df['date_local'].head()) # check few entries to check the format
# Out:
# 0    2024-01-03
# 4    2024-01-01
# 5    2024-01-02
# 28   2024-01-04
# 37   2024-01-05
# Name: date_local, dtype: datetime64[ns]

# %%
df['year'] = df['date_local'].dt.year #extracted year from date_local column and create a new column 'year'
df['month'] = df['date_local'].dt.month #extracted month from date_local column and create a new column 'month'

# %%
df.head()
# Out:
#     county_code  datum                 parameter date_local  \
# 0            33  WGS84  PM2.5 - Local Conditions 2024-01-03
# 4            33  WGS84  PM2.5 - Local Conditions 2024-01-01
# 5            33  WGS84  PM2.5 - Local Conditions 2024-01-02
# 28           33  WGS84  PM2.5 - Local Conditions 2024-01-04
# 37           33  WGS84  PM2.5 - Local Conditions 2024-01-05
#
#     observation_count  observation_percent validity_indicator  \
# 0                   1                100.0                  Y
# 4                   1                100.0                  Y
# 5                   1                100.0                  Y
# 28                  1                100.0                  Y
# 37                  1                100.0                  Y
#
#     arithmetic_mean  first_max_value  first_max_hour   aqi  method_code  \
# 0               4.9              4.9               0  27.0          170
# 4              20.0             20.0               0  71.0          170
# 5              14.8             14.8               0  62.0          170
# 28              3.6              3.6               0  20.0          170
# 37              4.6              4.6               0  26.0          170
#
#                                                method        local_site_name  \
# 0   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 4   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 5   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 28  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
# 37  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  Seattle-10th & Weller
#
#    county     city                         cbsa date_of_last_change  year  \
# 0    King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04  2024
# 4    King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04  2024
# 5    King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04  2024
# 28   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04  2024
# 37   King  Seattle  Seattle-Tacoma-Bellevue, WA          2025-04-04  2024
#
#     month
# 0       1
# 4       1
# 5       1
# 28      1
# 37      1
